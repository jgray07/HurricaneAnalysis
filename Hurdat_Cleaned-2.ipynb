# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from global_land_mask import globe
import reverse_geocoder as rg

# %% [markdown]
# # Build the Dataset

# %%
# Read in the Data
hurdat = pd.read_csv('hurdat.csv')
print(hurdat.shape)
print(hurdat.Code.nunique())
# Out:
# (52717, 22)
# 1924

# %%
hurdat.columns
# Out:
# Index(['Code', 'Name', 'Date', 'Time', 'Record Identifier', 'Storm Status',
#        'Latitude', 'Longitude', 'Max Sustained Wind Speed', 'Minumum Pressure',
#        '34 KT Wind Radii Max NE', '34 KT Wind Radii Max SE',
#        '34 KT Wind Radii Max SW', '34 KT Wind Radii Max NW',
#        '50 KT Wind Radii Max NE', '50 KT Wind Radii Max SE',
#        '50 KT Wind Radii Max SW', '50 KT Wind Radii Max NW',
#        '64 KT Wind Radii Max NE', '64 KT Wind Radii Max SE',
#        '64 KT Wind Radii Max SW', '64 KT Wind Radii Max NW'],
#       dtype='object')

# %%
# Create datetime column Date
hurdat['Date'] = pd.to_datetime(hurdat.Date,format='%Y%m%d', errors='ignore')

# %%
## Create day, month, year columns for visuals
hurdat['Day'] = hurdat['Date'].dt.day
hurdat['Month'] = hurdat['Date'].dt.month
hurdat['Year'] = hurdat['Date'].dt.year

# %%
### Create decade start and range for visuals
hurdat['Decade_Start'] = (hurdat['Year'] // 10) * 10 + 1

# ADJUST FOR YEARS ENDING IN ZERO
hurdat.loc[(hurdat['Year'] % 10) == 0, 'Decade_Start'] = hurdat['Decade_Start'] - 10

# CALCULATE DECADE RANGE
hurdat['Decade_Range'] = hurdat['Decade_Start'].astype('str') + ' - ' + \
                     (hurdat['Decade_Start'] + 9).astype('str')

# %% [markdown]
# ## Create Categories

# %%
#Based on windspeed
conditions = [
    ((hurdat['Max Sustained Wind Speed'] >= 64) & (hurdat['Max Sustained Wind Speed'] <= 82)),
    ((hurdat['Max Sustained Wind Speed'] >= 83) & (hurdat['Max Sustained Wind Speed'] <= 95)),
    ((hurdat['Max Sustained Wind Speed'] >= 96) & (hurdat['Max Sustained Wind Speed'] <= 112)),
    ((hurdat['Max Sustained Wind Speed'] >= 113) & (hurdat['Max Sustained Wind Speed'] <= 136)),
    (hurdat['Max Sustained Wind Speed'] >= 137)
    ]
values = [1, 2, 3, 4,5]
hurdat['Category'] = np.select(conditions, values)

# %% [markdown]
# ## Create Major Storm Category

# %%
conditions = [((hurdat['Category'] >= 0) & (hurdat['Category'] <=2)),
              (hurdat['Category'] >= 3)]
values = [0,1]
# 1 if a major storm ( 3 or higher), 0 otherwise
hurdat['Major Storm'] = np.select(conditions, values)

# %%
#How many storms become a major storm at some point?
hurdat[hurdat['Major Storm'] == 1]['Code'].nunique()
# Out:
# 325

# %% [markdown]
# ## Convert the latitude and longitude

# %%
def convert_coord(lat, long):
    '''Takes a string tuple for lattitude and longitude and returns the corresponding float tuple'''
    
    latitude, longitude = float(lat[:-1]), float(long[:-1])
    
    if lat[-1] == 'S': latitude *= -1
    if long[-1] == 'W': longitude *= -1
        
    return latitude, longitude

# %%
def convert_coords(coordinates):
    '''Takes a zipped list of latitudes and longitudes and returns a list of converted coordinates'''
    converted = []
    for coordinate in coordinates:
        converted.append(convert_coord(*coordinate))
    
    return converted

# %%
converted = list(zip(hurdat['Latitude'], hurdat['Longitude']))
converted = convert_coords(converted)
converted = pd.DataFrame(converted, columns=['Latitude_c', 'Longitude_c'])

# %%
hurdat = pd.concat([hurdat, converted], axis=1)

# %% [markdown]
# ## Find if a storm is on land

# %%
land = pd.DataFrame(list(
                    globe.is_land(hurdat['Latitude_c'],
                                  hurdat['Longitude_c'])),
                    columns = ['Land'])
land.sample(5)
# Out:
#         Land
# 42681  False
# 14383  False
# 23807  False
# 1428   False
# 14945   True

# %%
hurdat = pd.concat([hurdat,land],axis =1)

# %% [markdown]
# ## Find the State

# %%
coor = list(zip(hurdat['Latitude_c'],hurdat['Longitude_c']))
info = rg.search(coor)
state = pd.DataFrame(map(lambda x: x['admin1'],info),columns = ['State'])

# %%
hurdat = pd.concat([hurdat,state], axis = 1)

# %%
hurdat
# Out:
#            Code     Name       Date  Time Record Identifier Storm Status  \
# 0      AL011851  UNNAMED 1851-06-25     0               NaN           HU
# 1      AL011851  UNNAMED 1851-06-25   600               NaN           HU
# 2      AL011851  UNNAMED 1851-06-25  1200               NaN           HU
# 3      AL011851  UNNAMED 1851-06-25  1800               NaN           HU
# 4      AL011851  UNNAMED 1851-06-25  2100                 L           HU
# ...         ...      ...        ...   ...               ...          ...
# 52712  AL312020     IOTA 2020-11-17  1200               NaN           HU
# 52713  AL312020     IOTA 2020-11-17  1800               NaN           TS
# 52714  AL312020     IOTA 2020-11-18     0               NaN           TS
# 52715  AL312020     IOTA 2020-11-18   600               NaN           TS
# 52716  AL312020     IOTA 2020-11-18  1200               NaN           TD
#
#       Latitude Longitude  Max Sustained Wind Speed  Minumum Pressure  ...  \
# 0        28.0N     94.8W                        80              -999  ...
# 1        28.0N     95.4W                        80              -999  ...
# 2        28.0N     96.0W                        80              -999  ...
# 3        28.1N     96.5W                        80              -999  ...
# 4        28.2N     96.8W                        80              -999  ...
# ...        ...       ...                       ...               ...  ...
# 52712    13.7N     84.7W                        75               965  ...
# 52713    13.7N     85.7W                        55               988  ...
# 52714    13.8N     86.7W                        40              1000  ...
# 52715    13.8N     87.8W                        35              1005  ...
# 52716    13.7N     89.0W                        25              1006  ...
#
#        Month  Year  Decade_Start  Decade_Range  Category  Major Storm  \
# 0          6  1851          1851   1851 - 1860         1            0
# 1          6  1851          1851   1851 - 1860         1            0
# 2          6  1851          1851   1851 - 1860         1            0
# 3          6  1851          1851   1851 - 1860         1            0
# 4          6  1851          1851   1851 - 1860         1            0
# ...      ...   ...           ...           ...       ...          ...
# 52712     11  2020          2011   2011 - 2020         1            0
# 52713     11  2020          2011   2011 - 2020         0            0
# 52714     11  2020          2011   2011 - 2020         0            0
# 52715     11  2020          2011   2011 - 2020         0            0
# 52716     11  2020          2011   2011 - 2020         0            0
#
#        Latitude_c  Longitude_c   Land                   State
# 0            28.0        -94.8  False                   Texas
# 1            28.0        -95.4  False                   Texas
# 2            28.0        -96.0  False                   Texas
# 3            28.1        -96.5  False                   Texas
# 4            28.2        -96.8  False                   Texas
# ...           ...          ...    ...                     ...
# 52712        13.7        -84.7   True  Atlantico Norte (RAAN)
# 52713        13.7        -85.7   True           Nueva Segovia
# 52714        13.8        -86.7   True              El Paraiso
# 52715        13.8        -87.8   True                La Union
# 52716        13.7        -89.0   True               Cuscatlan
#
# [52717 rows x 33 columns]

# %%
hurdat["datetime"] = hurdat["Date"] + pd.to_timedelta(hurdat.Time.apply(lambda x: f"{x:04}").apply(lambda x: f"{str(x)[:2]} hours"))

# %%
# to normalize:
# .agg({"Latitude_c": lambda x: x/90, "Longitude_c": lambda x: x/180})
y = hurdat[["Code", "datetime", "Latitude_c","Longitude_c"]].set_index(["Code", "datetime"])
y
# Out:
#                      Latitude_c  Longitude_c
# datetime
# 1851-06-25 00:00:00        28.0        -94.8
# 1851-06-25 06:00:00        28.0        -95.4
# 1851-06-25 12:00:00        28.0        -96.0
# 1851-06-25 18:00:00        28.1        -96.5
# 1851-06-25 21:00:00        28.2        -96.8
# ...                         ...          ...
# 2020-11-17 12:00:00        13.7        -84.7
# 2020-11-17 18:00:00        13.7        -85.7
# 2020-11-18 00:00:00        13.8        -86.7
# 2020-11-18 06:00:00        13.8        -87.8
# 2020-11-18 12:00:00        13.7        -89.0
#
# [52717 rows x 2 columns]

# %%
hurdat['State'].unique()
# Out:
# array(['Texas', 'Veracruz', 'Eastern Tobago', 'Guyane', 'Saint Philip',
#        'Saint Joseph', '', 'Saint Anthony', 'Saint Croix Island',
#        'Arroyo', 'Cabo Rojo', 'San Pedro de Macoris', 'Barahona',
#        'Artibonite', 'Grandans', 'Santiago de Cuba', 'Las Tunas',
#        'Camaguey', 'Cienfuegos', 'Matanzas', 'La Habana', 'Artemisa',
#        'Pinar del Rio', 'Florida', 'Georgia', 'South Carolina',
#        'North Carolina', 'Virginia', 'Maryland', 'New York',
#        'Massachusetts', 'Nova Scotia', 'Miquelon-Langlade',
#        'Newfoundland and Labrador', 'North Abaco', 'Isabela', 'Samana',
#        'Maria Trinidad Sanchez', 'Mayaguana', 'Acklins', 'Ragged Island',
#        'Ciego de Avila', 'Villa Clara', 'Alabama', 'Mississippi',
#        'Guayama', 'Mayaguez', 'La Altagracia', 'Duarte',
#        'Santiago Rodriguez', 'Nord', 'Louisiana', 'Saint Peter',
#        'Barbuda', 'Saint Thomas Island', 'Loiza', 'Arecibo', 'Aguadilla',
#        'San Juan', 'Puerto Plata', 'Monte Cristi', 'Inagua',
#        'Crooked Island and Long Cay', 'San Salvador', 'Central Abaco',
#        'Hamilton city', 'Sud', 'Saint Thomas', 'St. Elizabeth',
#        'Westmoreland', 'Quintana Roo', 'Yucatan',
#        'Ribeira Grande de Santiago', 'Brava', 'Porto Novo',
#        'Saint-Pierre', 'Azores', 'Saint George', 'East Grand Bahama',
#        'West Grand Bahama', 'Nuevo Leon', 'Coahuila',
#        'Southern Peninsula', 'Atlantico Sur', 'Christ Church',
#        'Grenadines', 'Saint David', 'Anse-la-Raye', 'Guadeloupe',
#        'Santa Isabel Municipio', 'Santo Domingo', 'Santiago',
#        'Nord-Ouest', 'Nueva Esparta', 'Miranda', 'New Jersey',
#        'Saint Andrew', 'Guanica', 'Pedernales', 'Tamaulipas',
#        'Connecticut', 'Maine', 'Quebec', 'Ribeira Grande',
#        'Sint Eustatius', 'Delaware', 'Guantanamo', 'Cat Island',
#        'Central Eleuthera', 'Harbour Island', "Moore's Island",
#        'Freeport', 'Bimini', 'Tabasco', 'Campeche', 'Martinique',
#        'Saint James Windwa', 'Hatillo', 'Rhode Island', 'Colon',
#        'Kujalleq', 'Clarendon', 'Gracias a Dios', 'Bay Islands', 'Belize',
#        'Cayo', 'Archipielago de San Andres, Providencia y Santa Catalina',
#        'Saba', 'San Cristobal', 'Sud-Est', 'Portland', 'Saint Ann',
#        'Hanover', 'Isla de la Juventud', 'Arkansas', 'Saint Luke',
#        'Lajas', 'Hidalgo', 'Queretaro', 'Vega Alta', 'Long Island',
#        'Exuma', 'New Providence', 'Vermont', 'Atlantico',
#        'Saint John Capesterre', 'Saint John Island', 'Ciales',
#        'Independencia', 'Nippes', 'Ceara', 'Sermersooq', 'Granma',
#        'Sancti Spiritus', 'Mayabeque', 'Oklahoma', 'Culebra', 'Manati',
#        'Saint Michael', 'Dennery Quarter', 'Saint Patrick',
#        'North Andros', 'Peravia', 'Saint Mary', 'Holguin', 'Saint Lucy',
#        'Gros-Islet', 'Salinas', 'Prince Edward Island', 'San Lorenzo',
#        'Rincon', 'La Vega', 'Pennsylvania', 'Bonaire', 'La Guajira',
#        'Magdalena', 'Rivas', 'Managua', 'Chinandega', 'La Libertad',
#        'Guna Yala', 'New Brunswick', 'Vargas', 'Falcon', 'Black Point',
#        'Saint Mark', 'Commewijne', 'Pomeroon-Supenaam', 'Barima-Waini',
#        'Diego Martin', 'Ouest', 'West Virginia', 'Ontario',
#        'New Hampshire', 'Vieques Municipality', 'Ponce', 'La Romana',
#        'Kentucky', 'Kingston', 'Saint Thomas Middle Island', 'South',
#        'El Seibo', 'Munster', 'Wales', 'England', 'Connaught', 'Leinster',
#        'Rum Cay', 'Saint John', 'Trelawny',
#        'Carriacou and Petite Martinique', 'Charlotte', 'Ulster',
#        'Vieux-Fort', 'Puebla', 'Pays de la Loire', 'Bolivar', 'Limon',
#        'Tennessee', 'Ohio', 'Spanish Wells', 'San Jose de Ocoa',
#        'Valverde', 'Sao Vicente', 'Saint Paul Charlestown', 'Qeqqata',
#        'West', 'Atlantico Norte (RAAN)', 'Olancho',
#        'Santa Catarina do Fogo', 'Galicia', 'Michigan', 'Dakar',
#        'Boa Vista', 'Tarrafal', 'Tarrafal de Sao Nicolau', 'Tobago',
#        'Sucre', 'Orange Walk', 'Saint John Figtree', 'Maunabo', 'Sal',
#        'Micoud Quarter', 'Nunavut', 'Sabana Grande', 'Saint Paul',
#        'Sangre Grande', 'Tunapuna/Piarco', 'Saint George Gingerland',
#        'Saint Anne Sandy Point', 'Missouri', 'Illinois', 'Indiana',
#        'Patillas', 'Azua', 'Centre', 'Kansas', 'Iowa', 'Wisconsin',
#        'Bolama and Bijagos', 'Ziguinchor', 'Praia', 'Fajardo',
#        'Quebradillas', 'Monte Plata', 'Chiapas', 'Oaxaca',
#        'San Luis Potosi', 'Peten', 'Maio', 'Maranhao', 'Jinotega',
#        'Nueva Segovia', 'El Paraiso', 'Francisco Morazan', 'Yoro',
#        'Atlantida', 'Cortes', 'Stann Creek', 'Saint Thomas Lowland',
#        'Saint James', 'Matagalpa', 'Choluteca', 'La Union', 'La Paz',
#        'Ahuachapan', 'Escuintla', 'Trujillo Alto', 'Villalba',
#        'Choiseul Quarter', 'St Peter Port', 'Western', 'Retalhuleu',
#        'Soufriere', 'Luquillo', 'Ribeira Brava', 'Toledo', 'Northeast',
#        'East', 'Jan Mayen', 'Thies', 'Camuy', 'Arizona', 'Barceloneta',
#        'Nordland', 'Finnmark Fylke', 'Murmansk', 'Qaasuitsup', 'Cidra',
#        'Huehuetenango', 'Corozal', 'Mayaro', 'Point Fortin',
#        'Saint Catherine', 'Chontales', 'Quiche', 'San Marcos', 'Zacapa',
#        'Elias Pina', 'Lempira', 'Jutiapa', 'Canary Islands',
#        'Saint Mary Cayon', 'New Mexico', 'Madeira', 'Alta Verapaz',
#        'Guerrero', 'Michoacan', 'Colima', 'Jalisco', 'Nayarit',
#        'Nordoyar', 'Sonsonate', 'Santa Rosa', 'Guatemala', 'Sacatepequez',
#        'Scotland', 'Vagar', 'Svalbard', 'Nenetskiy Avtonomnyy Okrug',
#        'Komi Republic', 'Lisbon', 'Faro', 'Extremadura', 'Madrid',
#        'Castille and Leon', 'Aragon', 'Midi-Pyrenees', 'Northern Ireland',
#        'Sogn og Fjordane', 'More og Romsdal', 'Paul', 'Mosteiros',
#        'Suduroy', 'Troms', 'Brittany', 'Lower Normandy',
#        'Haute-Normandie', 'Rogaland', 'Hordaland', 'Castries Quarter',
#        'North Holland', 'Leiria', 'Tombali', 'Dakhlet Nouadhibou',
#        'Santa Catarina', 'Boke', 'Kolda', 'Lower River', 'Nouakchott',
#        'Asturias', 'Aquitaine', 'Limousin', 'Kaffrine', 'Kaolack',
#        'Saint-Louis', 'Para', 'Ngoebe-Bugle', 'Cocle', 'Veraguas',
#        'Conakry', 'Monsenor Nouel', 'Louga', 'Rio San Juan', 'Granada',
#        'Leon', 'Izabal', 'Heredia', 'Monagas', 'Anzoategui', 'Aragua',
#        'Lara', 'Espaillat', 'Zacatecas', 'San Sebastian', 'Humacao',
#        'Penuelas', 'Nacional', 'Cantabria', 'Nebraska', 'Yabucoa',
#        'Friesland', 'Vest-Agder', 'Central Jutland', 'Portalegre',
#        'Castille-La Mancha', 'Mexico', 'Sinaloa', 'Baja California Sur',
#        'Masaya', 'Guanajuato', 'Demerara-Mahaica', 'Princes Town',
#        'Zulia', 'Alajuela', 'Bocas del Toro', 'Barranquitas', 'Comayagua',
#        'Ocotepeque', 'Jalapa', 'Chimaltenango', 'Totonicapan',
#        'Delta Amacuro', 'Chihuahua', 'Cayey', 'Eysturoy',
#        'Nord-Trondelag', 'Andalusia', 'Souss-Massa-Draa', 'Tadla-Azilal',
#        'Ain Temouchent', 'Dorado', 'Sanchez Ramirez',
#        'Municipio de Juncos', 'Coimbra', 'Guarda', 'Capital Region',
#        'Northwest', 'Viana do Castelo', 'Santarem', 'Setubal',
#        'Grand Casablanca', 'Rabat-Sale-Zemmour-Zaer', 'Guanacaste',
#        'Viseu', 'Porto', 'Cuscatlan'], dtype=object)
